# %% [markdown]
# # Install Soda Core on Databricks
#
# Installs **Soda Core** (not Soda Library/Cloud) for programmatic Spark DataFrame scans.
#
# - No Soda Cloud account required
# - Run once per cluster, or add as cluster libraries
#
# Docs: [Connect Soda to Spark DataFrames](https://docs.soda.io/soda-documentation/soda-v3/data-source-reference/connect-spark#connect-to-spark-dataframes)

# %%
# DBTITLE 1,Install packages
# %pip install soda-core==3.3.22 soda-core-spark==3.3.22 soda-core-spark-df==3.3.22 pyyaml>=6.0

# %%
# DBTITLE 1,Restart Python
dbutils.library.restartPython()

# %%
# DBTITLE 1,Verify install
from soda.scan import Scan
from soda.__version__ import SODA_CORE_VERSION

print("Soda Core", SODA_CORE_VERSION, "installed")
print("Scan class:", Scan)
print("Ready — open tests_soda.ipynb to run data quality checks")

# %% [markdown]
# ## Optional: persist on cluster
#
# Add as cluster **Libraries** from PyPI so you do not reinstall after every restart:
#
# | Package | Version |
# |---------|---------|
# | `soda-core` | 3.3.22 |
# | `soda-core-spark` | 3.3.22 |
# | `soda-core-spark-df` | 3.3.22 |
# | `pyyaml` | 6.0+ |
#
# Then open **`tests_soda.ipynb`** to run data quality checks.
